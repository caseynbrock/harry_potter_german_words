# %%
# %matplotlib inline
import numpy as np
import mycount
import pandas as pd
import matplotlib.pyplot as plt

# %%
formatted_harry_txt = mycount.format_harry_potter('harry_potter_stein_weisen.txt')  # read and format harry potter text
kw_duolingo = mycount.read_known_word_list('duolingo_words_learned.txt')  # read list of known words
kw_2000 = mycount.read_known_word_list('german_vocab_2000.txt')
kw_characters = mycount.read_known_word_list('character_names.txt')
all_known_words = list(set(kw_duolingo) | set(kw_2000) | set(kw_characters))
b = mycount.Book(formatted_harry_txt, all_known_words)  # create Book object with harry potter data
df=b.word_data  # data frame of word statistics
pd.set_option('display.max_rows', 200)   # setting to print 200 lines of Pandas tables
# Out:
# Total number of words:  80428
# Number of unique words:  9475

# %% [markdown]
# How many new words are there?

# %%
print b.num_unique_words - len(b.known_words), ' new words'
# Out:
# 5759  new words

# %% [markdown]
# How many words appear only once in the book?

# %%
print len(df[df['word_count']==1]), ' words appear only once'
# Out:
# 5341  words appear only once

# %%
print len(df[(df['word_count']>5) & (df['learned']==False)]) # number of unlearned words that appear more than 5 times in book
# Out:
# 508

# %%
known_word_probability = df['word_count']/b.total_words
ax= plt.plot(np.cumsum(known_word_probability)*100)
plt.axvline(x=len(b.known_words), color='k')
plt.text(len(b.known_words)+50, 45, 'known words')
plt.xlabel('number of most popular words learned')
plt.ylabel('percent of Harry Potter words covered')
plt.xlim([0,b.num_unique_words])
plt.ylim([0,100])
plt.grid()
plt.show()

# %% [markdown]
# Print first 200 new words that appear more than five times in book, sorted by page on which they first appear. The total number of occurences of each word in the book are listed in the "count" column.

# %%
chunk = df[(df['word_count']>2) & (df['learned']==False)].sort_values(['page']).iloc[0:200]
chunk
# Out:
#                  word_count learned  page
# jahren                   15   False     5
# bohrmaschinen             3   False     5
# wäre                     53   False     5
# überlebt                  3   False     5
# ligusterweg              12   False     5
# 4                        11   False     5
# unerträglich              3   False     5
# wollten                  16   False     5
# könnte                   38   False     5
# besaß                     6   False     5
# würden                   30   False     5
# geheimnisvolle            4   False     5
# nachbarn                  3   False     5
# hätte                   106   False     5
# schnurrbart               7   False     5
# merkwürdige              10   False     5
# munter                    3   False     6
# wange                     3   False     6
# studierte                 3   False     6
# wutanfall                 3   False     6
# rückwärts                 6   False     6
# merkwürdigen             10   False     6
# merkwürdiges              4   False     6
# summte                    3   False     6
# griff                    19   False     6
# setzte                   31   False     6
# beginnt                   6   False     6
# gluckste                  6   False     6
# suchte                    6   False     6
# riesigen                 12   False     6
# solchen                   4   False     6
# wussten                  12   False     6
# dienstag                  3   False     6
# zwängte                   3   False     6
# fuhr                     21   False     6
# sollten                  32   False     6
# tages                    10   False     6
# wandte                   38   False     6
# rasch                    35   False     6
# versuchte                45   False     6
# fiel                     45   False     6
# wände                     7   False     6
# saß                      23   False     7
# starrte                  23   False     7
# nerven                    4   False     7
# smaragdgrünen             3   False     7
# gestalten                 4   False     7
# ausstehen                 4   False     7
# offenbar                 34   False     7
# umhang                   59   False     7
# trommelte                 3   False     7
# blinzelte                 6   False     7
# beobachtete               6   False     7
# fingern                   8   False     7
# bewegte                   5   False     7
# älter                     4   False     7
# trug                     23   False     7
# ruck                      4   False     7
# aufgeregt                11   False     7
# konnten                  42   False     7
# blickte                  38   False     7
# bemerken                  7   False     7
# stellte                  24   False     7
# katzen                    7   False     7
# mündern                   3   False     8
# eulen                    20   False     8
# andern                   47   False     8
# mehrere                   4   False     8
# angewurzelt               4   False     8
# wollte                   72   False     8
# deuteten                  4   False     8
# zornige                   3   False     8
# pack                      8   False     8
# schrie                   29   False     8
# wusste                   56   False     8
# hastig                    7   False     8
# lüfte                     6   False     8
# laune                     8   False     8
# tüte                      4   False     8
# schnappte                 5   False     8
# blicke                   10   False     8
# lauter                    5   False     8
# eule                     32   False     8
# nirgends                  4   False     8
# bemerkte                 22   False     8
# gewöhnlichen              4   False     8
# tage                      9   False     8
# warf                     37   False     8
# worte                    14   False     8
# fauchte                   9   False     8
# meisten                   7   False     8
# führte                   14   False     8
# blieb                    27   False     8
# daheim                    4   False     9
# fremder                   3   False     9
# schwerer                  6   False     9
# hieß                      7   False     9
# strich                    4   False     9
# jemandem                  4   False     9
# überlegte                 3   False     9
# vorbeigingen              5   False     9
# sagte                   702   False     9
# grummelte                 3   False     9
# einiges                   3   False     9
# nachdachte                3   False     9
# öffnete                  22   False     9
# verließ                   7   False     9
# weißt                    63   False     9
# schien                   49   False     9
# vorwurf                   3   False     9
# dannen                    3   False     9
# legte                    10   False     9
# blickten                  3   False     9
# hause                    11   False    10
# schhhh                    4   False    10
# grinsen                   9   False    10
# dieselbe                  4   False    10
# entschlossen              4   False    10
# eilte                     4   False    10
# hunderte                 10   False    10
# haustür                   4   False    10
# ungewöhnlich              4   False    10
# zischte                  10   False    10
# quer                      3   False    10
# male                      3   False    10
# brachte                  13   False    10
# hoffte                    3   False    10
# kreuz                     3   False    10
# erzählte                 15   False    10
# beobachtet                5   False    10
# fragte                   86   False    10
# mochte                   19   False    10
# ganze                    43   False    11
# flogen                    5   False    11
# entsetzt                 12   False    11
# räusperte                 3   False    11
# lippen                   13   False    11
# ahm                       5   False    11
# eiszapfen                 3   False    11
# sternschnuppen            5   False    11
# sessel                    6   False    11
# taten                     6   False    11
# wetter                    3   False    11
# meinte                   20   False    11
# murmelte                 31   False    11
# fragst                    6   False    12
# wartete                  11   False    12
# steif                     6   False    12
# lag                      33   False    12
# hinunter                 30   False    12
# hielt                    45   False    12
# stattdessen               6   False    12
# spähte                   11   False    12
# verlor                   10   False    12
# drehte                   28   False    12
# dudleys                  20   False    12
# bildete                   3   False    12
# gewöhnlicher              4   False    12
# rutschte                  4   False    12
# grunde                    7   False    13
# blinzeln                  4   False    13
# erschien                 13   False    13
# zeigte                   15   False    13
# purpurroten               4   False    13
# gerichtet                 8   False    13
# geradewegs                3   False    13
# gewachsen                 4   False    13
# statue                    3   False    13
# anblick                   9   False    13
# seines                   21   False    13
# mauer                     8   False    13
# ligusterwegs              3   False    13
# umhangs                   8   False    13
# hervor                   41   False    13
# hinüber                  27   False    13
# zuckte                    7   False    13
# funkelnd                  5   False    13
# silbernen                 6   False    13
# wurde                    71   False    13
# rührte                    5   False    13
# streifte                  3   False    13
# vergnügt                  6   False    13
# entfernte                 4   False    13
# irgendeinem               6   False    13
# gleiten                   6   False    14
# verwirrt                  4   False    14
# geschaut                  3   False    14
# wonach                    6   False    14
# laterne                   8   False    14
# lichter                   3   False    14
# brille                   10   False    14
# überraschung              6   False    14
# geschah                  12   False    14
# einzigen                  8   False    14
# feme                      4   False    14
# knipste                   3   False    14
# sprach                   18   False    14
# ließ                     82   False    14
# wären                     5   False    14
# dreinblickenden           3   False    14

# %% [markdown]
# List of 200 most frequent words.

# %%
df.iloc[0:200]
# Out:
#             word_count learned  page
# und               2393    True     5
# er                1820    True     5
# die               1716    True     5
# sie               1373    True     5
# der               1305    True     6
# harry             1220    True     8
# den               1037    True     5
# zu                1030    True     5
# in                1002    True     5
# nicht              931    True     5
# ich                877    True     8
# sich               851    True     5
# es                 843    True     5
# auf                841    True     5
# das                841    True     6
# ein                734    True     5
# war                729    True     5
# sagte              702   False     9
# mit                692    True     5
# ist                521    True     9
# du                 512    True     9
# hatte              485    True     5
# von                478    True     5
# dass               477    True     5
# dem                476    True     6
# wie                472    True     5
# an                 451    True     6
# als                446    True     6
# ihn                436    True     6
# was                418    True     5
# eine               408    True     5
# ron                405    True   104
# noch               395    True     6
# einen              371    True     5
# doch               364    True     5
# aus                354    True     6
# um                 346    True     6
# hagrid             332    True    18
# so                 323    True     5
# ihm                320    True     6
# wir                298    True     9
# wenn               294    True     5
# im                 283    True     5
# hat                272    True    11
# hermine            265    True   117
# vor                243    True     6
# einem              236    True     5
# ihr                234    True     6
# sein               231    True     5
# aber               219    True     5
# schon              214    True     5
# über               213    True     5
# nur                209    True     5
# für                208    True     6
# nach               206    True     6
# dann               200    True     6
# waren              193    True     5
# etwas              189    True     6
# konnte             189    True     5
# seine              181    True     6
# professor          180    True    14
# haben              179    True     5
# auch               176    True     5
# sah                169    True     6
# snape              166    True   139
# immer              164    True     7
# wieder             163    True     6
# da                 161    True     9
# mal                158    True     6
# mir                154    True    16
# dumbledore         150    True    13
# durch              148    True    15
# nun                147    True     8
# am                 147    True     6
# ihnen              145    True     6
# hier               144    True     8
# alle               143    True    15
# mich               141    True     9
# mehr               138    True     5
# ja                 137    True     7
# einer              135    True     5
# nichts             130    True     5
# dir                128    True    26
# hab                127    True     8
# würde              124    True     5
# jetzt              122    True     7
# dich               121    True    21
# hatten             121    True     5
# zum                121    True     6
# sind               119    True    11
# onkel              119    True    18
# seinen             119    True     6
# dudley             118    True     5
# malfoy             116    True   120
# gut                113    True    16
# oder               112    True    11
# uns                111    True     9
# vernon             109    True    26
# sehr               109    True     5
# seinem             109    True     6
# kopf               108    True     6
# augen              108    True     5
# denn               108    True     5
# bei                107    True     6
# hätte              106   False     5
# des                105    True    11
# alles              104    True     5
# wo                 104    True    10
# ganz               104    True     5
# nie                104    True     6
# sehen              102    True     6
# neville            100    True   105
# potter             100    True     5
# man                100    True     5
# ihre                99    True     5
# mcgonagall          97    True    14
# tür                 96    True    22
# euch                94    True    35
# weiß                93    True    15
# sagen               92    True     5
# quirrell            92    True    79
# keine               92    True     5
# gerade              92    True     6
# einmal              91    True     6
# hinter              90    True    10
# kann                89    True     9
# gesicht             89    True     9
# hast                88    True    11
# harrys              88    True    21
# s                   87   False    17
# fragte              86   False    10
# ging                84    True     6
# vielleicht          83    True     7
# ob                  83    True     8
# ließ                82   False    14
# kam                 82    True     9
# können              82    True    10
# vom                 82    True     8
# weg                 81    True     8
# werden              79    True     8
# fast                79    True     5
# hand                78    True     8
# wird                77   False    19
# hogwarts            77    True    56
# bin                 76    True     9
# habe                76    True    14
# mr                  76    True     5
# zurück              75    True     6
# während             74    True     6
# bis                 73    True     8
# viel                73    True     5
# stimme              72    True     9
# wollte              72   False     8
# besen               72   False    76
# gryffindor          72    True   118
# zur                 72    True     8
# wurde               71   False    13
# boden               71    True    13
# stand               71    True     6
# plötzlich           71    True     7
# diesem              71    True     8
# kein                70    True     6
# seiner              70    True     6
# unter               68    True    18
# stein               67    True    80
# nein                67    True     7
# rief                67   False    18
# paar                67    True     7
# einfach             67    True     5
# gesehen             66    True     5
# gab                 66    True     5
# musste              66    True     7
# tante               66    True    18
# gegen               65    True    16
# los                 65    True    15
# wer                 64    True     9
# tun                 63    True     5
# wenig               63    True     8
# weißt               63   False     9
# davon               63    True    16
# hoch                63    True     8
# blick               62    True     7
# ab                  62    True    31
# gesagt              61    True    16
# bist                61    True    25
# warum               60    True     8
# selbst              60    True     9
# umhang              59   False     7
# luft                58    True    14
# muss                58    True    15
# petunia             57    True    11
# anderen             57   False    22
# müssen              57    True    13
# wusste              56   False     8
# eines               56    True     6
# junge               55    True     5
# schule              55    True    30
# dursley             54    True     5
# machte              54    True     8
# großen              54    True     5

# %% [markdown]
# Table of 200 most frequent unlearned words.

# %%
df[df['learned']==False].iloc[0:200]
# Out:
#                    word_count learned  page
# sagte                     702   False     9
# hätte                     106   False     5
# s                          87   False    17
# fragte                     86   False    10
# ließ                       82   False    14
# wird                       77   False    19
# wollte                     72   False     8
# besen                      72   False    76
# wurde                      71   False    13
# rief                       67   False    18
# weißt                      63   False     9
# umhang                     59   False     7
# anderen                    57   False    22
# wusste                     56   False     8
# zog                        54   False    18
# wäre                       53   False     5
# wood                       53   False   166
# zauberstab                 52   False    69
# schien                     49   False     9
# andern                     47   False     8
# fiel                       45   False     6
# versuchte                  45   False     6
# hielt                      45   False    12
# ganze                      43   False    11
# konnten                    42   False     7
# hervor                     41   False    13
# zauberer                   39   False    58
# flüsterte                  39   False    20
# punkte                     38   False   127
# wandte                     38   False     6
# könnte                     38   False     5
# blickte                    38   False     7
# warf                       37   False     8
# hörte                      36   False    25
# rasch                      35   False     6
# offenbar                   34   False     7
# lag                        33   False    12
# sollten                    32   False     6
# sahen                      32   False    21
# eule                       32   False     8
# setzte                     31   False     6
# murmelte                   31   False    11
# hinunter                   30   False    12
# standen                    30   False    21
# würden                     30   False     5
# schlug                     29   False    28
# schrie                     29   False     8
# drehte                     28   False    12
# glaube                     28   False    62
# hinüber                    27   False    13
# begann                     27   False    25
# blieb                      27   False     8
# gringotts                  26   False    72
# sprang                     26   False    18
# tut                        26   False    35
# erstklässler               25   False    76
# troll                      25   False   131
# stellte                    24   False     7
# trat                       23   False    21
# trug                       23   False     7
# mannschaft                 23   False   111
# saß                        23   False     7
# schwarzen                  23   False    55
# starrte                    23   False     7
# hütte                      22   False    51
# werde                      22   False    16
# dunklen                    22   False    26
# bemerkte                   22   False     8
# kommt                      22   False    19
# öffnete                    22   False     9
# mum                        22   False    55
# schrank                    22   False    25
# hob                        21   False    34
# fuhr                       21   False     6
# kessel                     21   False    76
# seines                     21   False    13
# atem                       21   False    17
# zauberei                   20   False    59
# meinte                     20   False    11
# spürte                     20   False    91
# quirrells                  20   False   139
# eulen                      20   False     8
# rannte                     20   False    39
# dudleys                    20   False    12
# allen                      19   False    38
# hörten                     19   False    29
# griff                      19   False     6
# stieß                      19   False    21
# deutete                    19   False    15
# mochte                     19   False    10
# rons                       18   False   111
# allmählich                 18   False    34
# musst                      18   False    58
# stieg                      18   False    21
# fand                       18   False    25
# gewusst                    18   False    61
# narbe                      18   False    20
# sprach                     18   False    14
# großer                     17   False    31
# piers                      17   False    29
# riss                       17   False    28
# schnatz                    17   False   186
# schüttelte                 17   False    34
# wollten                    16   False     5
# klatscher                  16   False   185
# packte                     16   False    43
# streckte                   16   False    17
# erklärte                   16   False    47
# ohren                      16   False   111
# mussten                    16   False    15
# steckte                    16   False    18
# sucher                     15   False   166
# zeigte                     15   False    13
# aussah                     15   False    20
# antwortete                 15   False    51
# aller                      15   False    28
# lächelte                   15   False    14
# fühlte                     15   False    56
# päckchen                   15   False    27
# wirst                      15   False    44
# händen                     15   False    51
# dritten                    15   False    69
# sagt                       15   False    87
# zweitausend                15   False    81
# jahren                     15   False     5
# erzählte                   15   False    10
# schienen                   15   False    37
# klassenzimmer              15   False   145
# willst                     15   False    72
# weisen                     14   False   239
# gleis                      14   False    99
# kröte                      14   False    76
# armen                      14   False    20
# flint                      14   False   203
# worte                      14   False     8
# verschwand                 14   False    22
# führte                     14   False     8
# jeden                      14   False    51
# saßen                      14   False    35
# klopfte                    14   False    17
# turban                     14   False   135
# korridor                   14   False   145
# brach                      13   False    39
# erschien                   13   False    13
# rosa                       13   False    24
# brachte                    13   False    10
# zaubern                    13   False    68
# lippen                     13   False    11
# gestalt                    13   False   141
# folgte                     13   False    50
# glaubst                    13   False    72
# gemeinschaftsraum          13   False   127
# schob                      13   False    77
# klatschte                  13   False    40
# ließen                     13   False    79
# lautes                     13   False    54
# ohnehin                    13   False    30
# erinnerte                  13   False    24
# dicht                      13   False    35
# schoss                     12   False    95
# stöhnte                    12   False    25
# bekam                      12   False    26
# wussten                    12   False     6
# vertrauensschüler          12   False   107
# entsetzt                   12   False    11
# lief                       12   False    27
# nickte                     12   False    17
# ligusterweg                12   False     5
# bewacht                    12   False    73
# riesigen                   12   False     6
# schreck                    12   False    28
# hinweg                     12   False    55
# nevilles                   12   False   118
# hättest                    12   False    74
# geschah                    12   False    14
# köpfen                     12   False    80
# rannten                    12   False    35
# großes                     12   False    21
# jordan                     11   False   109
# könne                      11   False    39
# glaubt                     11   False    35
# wartete                    11   False    12
# 1                          11   False    59
# zettel                     11   False   218
# bahnhof                    11   False    74
# hause                      11   False    10
# empor                      11   False    74
# drang                      11   False    81
# jemanden                   11   False    48
# bahnsteig                  11   False   101
# stürzte                    11   False    53
# aufgeregt                  11   False     7
# machten                    11   False    28
# turm                       11   False   137
# spähte                     11   False    12
# verzweifelt                11   False   102
# schwierigkeiten            11   False    31
# könntest                   11   False    62
# malfoys                    11   False   158
# 4                          11   False     5
